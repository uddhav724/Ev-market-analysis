# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("Ev data 1.zip")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       103 non-null    int64
#  1   Brand            103 non-null    object
#  2   Model            103 non-null    object
#  3   AccelSec         103 non-null    float64
#  4   TopSpeed_KmH     103 non-null    int64
#  5   Range_Km         103 non-null    int64
#  6   Efficiency_WhKm  103 non-null    int64
#  7   FastCharge_KmH   103 non-null    int64
#  8   RapidCharge      103 non-null    object
#  9   PowerTrain       103 non-null    object
#  10  PlugType         103 non-null    object
#  11  BodyStyle        103 non-null    object
#  12  Segment          103 non-null    object
#  13  Seats            103 non-null    int64
#  14  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 12.2+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0        Brand                          Model  AccelSec  \
# 0           0       Tesla   Model 3 Long Range Dual Motor       4.6
# 1           1  Volkswagen                       ID.3 Pure      10.0
# 2           2    Polestar                               2       4.7
# 3           3         BMW                            iX3        6.8
# 4           4       Honda                              e        9.5
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
# 2           210       400              181             620         Yes
# 3           180       360              206             560         Yes
# 4           145       170              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# 0        AWD  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0    Brand                            Model  AccelSec  \
# 98           98  Nissan                       Ariya 63kWh       7.5
# 99           99    Audi     e-tron S Sportback 55 quattro       4.5
# 100         100  Nissan               Ariya e-4ORCE 63kWh       5.9
# 101         101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1
# 102         102   Byton                 M-Byte 95 kWh 2WD       7.5
#
#      TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 98            160       330              191             440         Yes
# 99            210       335              258             540         Yes
# 100           200       325              194             440         Yes
# 101           200       375              232             450         Yes
# 102           190       400              238             480          No
#
#     PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  \
# count  103.000000  103.000000    103.000000  103.000000       103.000000
# mean    51.000000    7.396117    179.194175  338.786408       189.165049
# std     29.877528    3.017430     43.573030  126.014444        29.566839
# min      0.000000    2.100000    123.000000   95.000000       104.000000
# 25%     25.500000    5.100000    150.000000  250.000000       168.000000
# 50%     51.000000    7.300000    160.000000  340.000000       180.000000
# 75%     76.500000    9.000000    200.000000  400.000000       203.000000
# max    102.000000   22.400000    410.000000  970.000000       273.000000
#
#        FastCharge_KmH       Seats      PriceEuro
# count      103.000000  103.000000     103.000000
# mean       444.271845    4.883495   55811.563107
# std        203.949253    0.795834   34134.665280
# min        170.000000    2.000000   20129.000000
# 25%        260.000000    5.000000   34429.500000
# ...

# %%
data[['Brand','TopSpeed_KmH']].head()
# Out:
#          Brand  TopSpeed_KmH
# 0       Tesla            233
# 1  Volkswagen            160
# 2    Polestar            210
# 3         BMW            180
# 4       Honda            145

# %%
data[['Brand','TopSpeed_KmH']].tail()
# Out:
#        Brand  TopSpeed_KmH
# 98   Nissan            160
# 99     Audi            210
# 100  Nissan            200
# 101  Nissan            200
# 102   Byton            190

# %%
data[data['TopSpeed_KmH']>200]
# Out:
#     Unnamed: 0      Brand                           Model  AccelSec  \
# 0            0     Tesla    Model 3 Long Range Dual Motor       4.6
# 2            2  Polestar                                2       4.7
# 5            5     Lucid                             Air        2.8
# 8            8     Tesla      Model 3 Standard Range Plus       5.6
# 16          16   Porsche                   Taycan Turbo S       2.8
# 21          21     Tesla    Model Y Long Range Dual Motor       5.1
# 23          23      Audi                       e-tron GT        3.5
# 24          24     Tesla   Model 3 Long Range Performance       3.4
# 33          33     Tesla             Cybertruck Tri Motor       3.0
# 40          40     Tesla               Model S Long Range       3.8
# 47          47   Porsche                        Taycan 4S       4.0
# 51          51     Tesla                        Roadster        2.1
# 54          54     Tesla               Model X Long Range       4.6
# ...

# %%
data[data['PriceEuro']>50000]
# Out:
#      Unnamed: 0       Brand                            Model  AccelSec  \
# 0             0      Tesla     Model 3 Long Range Dual Motor       4.6
# 2             2   Polestar                                 2       4.7
# 3             3        BMW                              iX3        6.8
# 5             5      Lucid                              Air        2.8
# 9             9       Audi                        Q4 e-tron        6.3
# 10           10   Mercedes                    EQC 400 4MATIC       5.1
# 13           13        BMW                               i4        4.0
# 16           16    Porsche                    Taycan Turbo S       2.8
# 21           21      Tesla     Model Y Long Range Dual Motor       5.1
# 23           23       Audi                        e-tron GT        3.5
# 24           24      Tesla    Model 3 Long Range Performance       3.4
# 27           27      Volvo              XC40 P8 AWD Recharge       4.9
# ...

# %%
data[data['PriceEuro']<50000]
# Out:
#     Unnamed: 0        Brand                        Model  AccelSec  \
# 1            1  Volkswagen                     ID.3 Pure      10.0
# 4            4       Honda                            e        9.5
# 6            6  Volkswagen                       e-Golf        9.6
# 7            7     Peugeot                        e-208        8.1
# 8            8       Tesla   Model 3 Standard Range Plus       5.6
# 11          11      Nissan                         Leaf        7.9
# 12          12     Hyundai          Kona Electric 64 kWh       7.9
# 14          14     Hyundai                IONIQ Electric       9.7
# 15          15  Volkswagen                    ID.3 Pro S       7.9
# 17          17  Volkswagen                        e-Up!       11.9
# 18          18          MG                         ZS EV       8.2
# 19          19        Mini                    Cooper SE        7.3
# 20          20        Opel                      Corsa-e        8.1
# ...

# %%
plt.scatter(data['TopSpeed_KmH'],data['Range_Km'],color='red')
plt.title('TopSpeed vs Range')
plt.xlabel('TopSpeed')
plt.ylabel('Range pre KM')
plt.show()

# %%
sb.regplot(x=data['AccelSec'], y=data['Efficiency_WhKm'], ci=None, line_kws={"color": "red"})
plt.title('Acceleration  vs Efficiency')
plt.xlabel('Acceleration speed')
plt.ylabel('Efficiency')
plt.show()

# %%
sb.regplot(x=data['TopSpeed_KmH'], y=data['Range_Km'], ci=None, line_kws={"color": "red"})
plt.title('TopSpeed vs Range')
plt.xlabel('TopSpeed')
plt.ylabel('Range pre KM')
plt.show()

# %%
data.plot(kind='bar',x='Brand',y='PriceEuro')
plt.xlabel('Brand')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
data_numeric=data.select_dtypes(include=['number'])
cor=data_numeric.corr()
plt.figure(figsize=(8, 6)) 
sb.heatmap(cor, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation heatmap')
plt.show()
